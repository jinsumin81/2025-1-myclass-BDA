# %% [markdown]
# <a href="https://colab.research.google.com/github/jinsumin81/2025-1-myclass-BDA/blob/main/inclass/05w_A_mon_0407_easy_ch05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##05주 수업

# %% [markdown]
# ## 05-3 파생변수 생성 p116

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'var1':[4,3,8], 'var2' : [2, 6,1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1 = df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum'] = df1.var1+ df1.var2
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1.var_sum2 = df1.var1+ df1.var2
df1
# Out:
# <ipython-input-5-6f1bf501a747>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.var_sum2 = df1.var1+ df1.var2
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1['var_sum'] = (df1.var1+ df1.var2)/2
df1
# Out:
#    var1  var2  var_sum
# 0     4     2      3.0
# 1     3     6      4.5
# 2     8     1      4.5

# %%
df1
# Out:
#    var1  var2  var_sum
# 0     4     2      3.0
# 1     3     6      4.5
# 2     8     1      4.5

# %%
df2 = df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2.sum()
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis = 0)
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis = 1)
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df2['my_sum']= df2.sum(axis = 1)
df2
# Out:
#    var1  var2  my_sum
# 0     4     2       6
# 1     3     6       9
# 2     8     1       9
